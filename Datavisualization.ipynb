# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")

df = pd.read_csv('2019.csv')

# Display basic information
print("Dataset Preview:")
print(df.head())
print("\nColumns:")
print(df.columns)

# Rename columns for convenience
df.columns = df.columns.str.replace(' ', '_')

# ================================
# 🔹 Top 10 Happiest Countries
# ================================

top10 = df.sort_values('Score', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=top10, x='Score', y='Country_or_region', palette='YlGnBu')
plt.title('Top 10 Happiest Countries in 2019')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# ================================
# 🔹 Bottom 10 Least Happy Countries
# ================================

bottom10 = df.sort_values('Score', ascending=True).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=bottom10, x='Score', y='Country_or_region', palette='OrRd')
plt.title('Bottom 10 Least Happy Countries in 2019')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# ================================
# 🔹 Correlation Heatmap
# ================================

# Selecting relevant columns
features = df[['Score', 'GDP_per_capita', 'Social_support',
               'Healthy_life_expectancy', 'Freedom_to_make_life_choices',
               'Generosity', 'Perceptions_of_corruption']]

# Correlation Matrix
plt.figure(figsize=(10, 7))
sns.heatmap(features.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Between Happiness Factors')
plt.tight_layout()
plt.show()

# ================================
# 🔹 Scatter Plot: GDP vs Happiness Score
# ================================

plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='GDP_per_capita', y='Score', hue='Country_or_region', legend=False)
plt.title('Happiness vs GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.tight_layout()
plt.show()

# ================================
# 🔹 Pair Plot: Multivariate Relationship
# ================================

sns.pairplot(features)
plt.suptitle("Relationships Between Happiness Factors", y=1.02)
plt.show()
# Out:
# Dataset Preview:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
pip install pandas matplotlib seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('2019.csv')
df.columns = df.columns.str.replace(' ', '_')

top10 = df.sort_values('Score', ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(data=top10, x='Score', y='Country_or_region', palette='Blues_r')
plt.title('Top 10 Happiest Countries in 2019')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-3-2f35cdd609a2>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top10, x='Score', y='Country_or_region', palette='Blues_r')

# %%
bottom10 = df.sort_values('Score', ascending=True).head(10)

plt.figure(figsize=(10,6))
sns.barplot(data=bottom10, x='Score', y='Country_or_region', palette='Reds')
plt.title('Bottom 10 Least Happy Countries in 2019')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-4-070ca70f63cc>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=bottom10, x='Score', y='Country_or_region', palette='Reds')

# %%
plt.figure(figsize=(10, 7))
features = df[['Score', 'GDP_per_capita', 'Social_support',
               'Healthy_life_expectancy', 'Freedom_to_make_life_choices',
               'Generosity', 'Perceptions_of_corruption']]

sns.heatmap(features.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Between Happiness Factors')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='GDP_per_capita', y='Score')
plt.title('Happiness vs GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Social_support', y='Score', color='green')
plt.title('Happiness vs Social Support')
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.show()

# %%
# Only run this if Region column exists
if 'Region' in df.columns:
    plt.figure(figsize=(12,6))
    sns.boxplot(data=df, x='Region', y='Score')
    plt.xticks(rotation=45)
    plt.title('Distribution of Happiness Score by Region')
    plt.show()
else:
    print("No 'Region' column found in this version of the dataset.")
# Out:
# No 'Region' column found in this version of the dataset.

# %%
sns.pairplot(features)
plt.suptitle('Relationships Between Happiness Factors', y=1.02)
plt.show()
